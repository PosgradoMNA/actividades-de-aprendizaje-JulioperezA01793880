# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-JulioperezA01793880/blob/main/Copia_de_Modulo4_IBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Modulo 4 Ibm, aqui estamos practicando lectura de archivos, se hizo practicas en jupiter notebook.
# para comprender mejor el la informacion cree un aarchivo en le escritorio y lo abri y lei desde python.

# %%
import pandas as pd
archi1=open(r"C:\Users\Gabi\Desktop\prueba python.txt","r")
contenido=archi1.read()
print(contenido)
archi1.close()

# %% [markdown]
# Ahora por medio del codigo abajo escribimos en modo agregar sobre un archivo local ubicado en el escritorio escribimo un "hola mundo 2" y el archivo de texto aparecio el hola mundo 2.

# %%
archi1=open(r"C:\Users\Gabi\Desktop\prueba python.txt","a")
contenido=archi1.write(" hola mundo 2 \n")
archi1=open(r"C:\Users\Gabi\Desktop\prueba python.txt","r")
contenido=archi1.read()
print(contenido)
archi1.close()

# %% [markdown]
# Ahora, comienzo a practicar con datos atraves de datos, traigo de github el archivo scv usado el laboratoria de jupiter notebook usado en el curso ibm, y muestro todos los datos.

# %%
import pandas as pd

print("hola")
df=pd.read_csv('https://raw.githubusercontent.com/hannansatopay/DSML/master/TopSellingAlbums.csv')
df
# Out:
# hola
#             Artist                            Album  Released   Length  \
# 0  Michael Jackson                         Thriller      1982  0:42:19
# 1            AC/DC                    Back in Black      1980  0:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# ...

# %% [markdown]
# ahora mostramos las 5 primeras filas con el funcion head.

# %%
df=pd.read_csv('https://raw.githubusercontent.com/hannansatopay/DSML/master/TopSellingAlbums.csv')
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %% [markdown]
# ahora vamos a aceder a diferentes columnas del archivo

# %% [markdown]
# Uso de la Libreria pandas

# %%
y = df[['Artist','Length','Genre']]
y
# Out:
#             Artist   Length                        Genre
# 0  Michael Jackson  0:42:19               pop, rock, R&B
# 1            AC/DC  0:42:11                    hard rock
# 2       Pink Floyd  0:42:49             progressive rock
# 3  Whitney Houston  0:57:44               R&B, soul, pop
# 4        Meat Loaf  0:46:33  hard rock, progressive rock
# 5           Eagles  0:43:08   rock, soft rock, folk rock
# 6         Bee Gees  1:15:54                        disco
# 7    Fleetwood Mac  0:40:01                    soft rock

# %% [markdown]
# Con la siguiente funcion accedemos a las columnas y filas que parametricemos con iloc para el caso que sigue se accede a 2 filas, 4 columnas

# %%
df.iloc[0:2, 0:4]
# Out:
#             Artist          Album  Released   Length
# 0  Michael Jackson       Thriller      1982  0:42:19
# 1            AC/DC  Back in Black      1980  0:42:11

# %% [markdown]
# se almacena en la varible q, la columna rating

# %%
q = df['Rating']
q
# Out:
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5
# Name: Rating, dtype: float64

# %% [markdown]
# se almacen en la variable q las viarable artist y release.

# %%
q = df[['Rating','Artist']]
q
# Out:
#    Rating           Artist
# 0    10.0  Michael Jackson
# 1     9.5            AC/DC
# 2     9.0       Pink Floyd
# 3     8.5  Whitney Houston
# 4     8.0        Meat Loaf
# 5     7.5           Eagles
# 6     7.0         Bee Gees
# 7     6.5    Fleetwood Mac

# %%
new_index=['a','b','c','d','e','f','g','h']
df_new=df
df_new.index=new_index
df_new.loc['a', 'Artist']
df_new.loc['a':'d', 'Artist']
# Out:
# a    Michael Jackson
# b              AC/DC
# c         Pink Floyd
# d    Whitney Houston
# Name: Artist, dtype: object

# %% [markdown]
# Practica con pandas para agregar una nueva columna de datos.

# %%
df['letras']=['j','k','l','m','n','p','q','r',]
df
# Out:
#             Artist                            Album  Released   Length  \
# a  Michael Jackson                         Thriller      1982  0:42:19
# b            AC/DC                    Back in Black      1980  0:42:11
# c       Pink Floyd        The Dark Side of the Moon      1973  0:42:49
# d  Whitney Houston                    The Bodyguard      1992  0:57:44
# e        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# f           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# g         Bee Gees             Saturday Night Fever      1977  1:15:54
# h    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# a               pop, rock, R&B                              46.0
# b                    hard rock                              26.1
# c             progressive rock                              24.2
# d               R&B, soul, pop                              27.4
# ...

# %% [markdown]
# practica de pandas agregando nueva fila de informacion con la funcion append

# %%
from pandas.io.formats.style_render import DataFrame
nueva_fila={'Artist':'julio','Album':'Victoria','Released':'2022','Length':'00:43','Genre':'Romantic','Music Recording Sales (millions)':'100','Claimed Sales (millions)':'80','Released.1':'1-october-22','Soundtrack':'','Rating':'10','letras':'z'}
df=df.append(nueva_fila,ignore_index=True)
df
# Out:
#              Artist                            Album Released   Length  \
# 0   Michael Jackson                         Thriller     1982  0:42:19
# 1             AC/DC                    Back in Black     1980  0:42:11
# 2        Pink Floyd        The Dark Side of the Moon     1973  0:42:49
# 3   Whitney Houston                    The Bodyguard     1992  0:57:44
# 4         Meat Loaf                  Bat Out of Hell     1977  0:46:33
# 5            Eagles  Their Greatest Hits (1971-1975)     1976  0:43:08
# 6          Bee Gees             Saturday Night Fever     1977  1:15:54
# 7     Fleetwood Mac                          Rumours     1977  0:40:01
# 8               NaN                         Victoria     2022    00:43
# 9             julio                         Victoria     2022    00:43
# 10            julio                         Victoria     2022    00:43
#
#                           Genre Music Recording Sales (millions)  \
# ...

# %%
df
# Out:
#             Artist                            Album  Released   Length  \
# a  Michael Jackson                         Thriller      1982  0:42:19
# b            AC/DC                    Back in Black      1980  0:42:11
# c       Pink Floyd        The Dark Side of the Moon      1973  0:42:49
# d  Whitney Houston                    The Bodyguard      1992  0:57:44
# e        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# f           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# g         Bee Gees             Saturday Night Fever      1977  1:15:54
# h    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# a               pop, rock, R&B                              46.0
# b                    hard rock                              26.1
# c             progressive rock                              24.2
# d               R&B, soul, pop                              27.4
# ...

# %%
import pandas as banana

df=banana.DataFrame({'a':[11,21,31],'b':[21,22,23]})

df.head()
# Out:
#     a   b
# 0  11  21
# 1  21  22
# 2  31  23

# %% [markdown]
# > obtener las 3 primeras filas

# %%
df.head(3)
# Out:
#     a   b
# 0  11  21
# 1  21  22
# 2  31  23

# %% [markdown]
# obtener columna a

# %%
df['a']
# Out:
# 0    11
# 1    21
# 2    31
# Name: a, dtype: int64
