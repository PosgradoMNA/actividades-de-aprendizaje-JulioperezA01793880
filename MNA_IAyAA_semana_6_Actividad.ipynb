# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-JulioperezA01793880/blob/main/MNA_IAyAA_semana_6_Actividad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Inteligencia Artificial y Aprendizaje Automático**
# ###Tecnológico de Monterrey
# ###Prof Luis Eduardo Falcón Morales
#
# ## **Adtividad de la Semana 6**
# ###**Árboles de decisión y bosque aleatorio.**

# %% [markdown]
# **Nombres y matrículas de los integrantes del equipo:**
#
# *
# *
# *
# *
# *

# %% [markdown]
# En cada sección deberás incluir todas las líneas de código necesarias para responder a cada uno de los ejercicios.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn import linear_model
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
# %matplotlib inline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder, MinMaxScaler
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score         
from sklearn.metrics import classification_report, make_scorer
from imblearn.metrics import geometric_mean_score, classification_report_imbalanced
from sklearn.model_selection import  cross_validate,  RepeatedStratifiedKFold

# %% [markdown]
# #**Ejercicio-1.**

# %%
from google.colab import files 
  
  
uploaded = files.upload()
import io
# Out:
#      <input type="file" id="files-effda488-df79-4a80-b00f-d53a1b19683d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-effda488-df79-4a80-b00f-d53a1b19683d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(io.BytesIO(uploaded['index.csv'])) 
df.rename(columns={'Payment Status of Previous Credit':'status','Duration of Credit (month)':'duration','Credit Amount':'amount'},
               inplace=True)

df.head(20)
# Out:
#     Creditability  Account Balance  duration  status  Purpose  amount  \
# 0               1                1        18       4        2    1049
# 1               1                1         9       4        0    2799
# 2               1                2        12       2        9     841
# 3               1                1        12       4        0    2122
# 4               1                1        12       4        0    2171
# 5               1                1        10       4        0    2241
# 6               1                1         8       4        0    3398
# 7               1                1         6       4        0    1361
# 8               1                4        18       4        3    1098
# 9               1                2        24       2        3    3758
# 10              1                1        11       4        0    3905
# 11              1                1        30       4        1    6187
# ...

# %%
df.dtypes
# Out:
# Creditability                    int64
# Account Balance                  int64
# duration                         int64
# status                           int64
# Purpose                          int64
# amount                           int64
# Value Savings/Stocks             int64
# Length of current employment     int64
# Instalment per cent              int64
# Sex & Marital Status             int64
# Guarantors                       int64
# Duration in Current address      int64
# Most valuable available asset    int64
# Age (years)                      int64
# Concurrent Credits               int64
# Type of apartment                int64
# No of Credits at this Bank       int64
# Occupation                       int64
# No of dependents                 int64
# Telephone                        int64
# Foreign Worker                   int64
# dtype: object

# %% [markdown]
# #**Ejercicio-2.**

# %%
X = np.array(df.drop(['Creditability'],1))
y = np.array(df['Creditability'])
X.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# (1000, 20)

# %%
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, y, test_size=0.15, random_state=7)

# %% [markdown]
# #**Ejercicio-3.**

# %%
df.isna().sum()
# Out:
# Creditability                    0
# Account Balance                  0
# duration                         0
# status                           0
# Purpose                          0
# amount                           0
# Value Savings/Stocks             0
# Length of current employment     0
# Instalment per cent              0
# Sex & Marital Status             0
# Guarantors                       0
# Duration in Current address      0
# Most valuable available asset    0
# Age (years)                      0
# Concurrent Credits               0
# Type of apartment                0
# No of Credits at this Bank       0
# Occupation                       0
# No of dependents                 0
# Telephone                        0
# Foreign Worker                   0
# dtype: int64

# %%
scaler = MinMaxScaler()
 
#df_scaled = scaler.fit_transform(df())
#df_scaled = pd.DataFrame(df_scaled, columns=[
 # 'duration', 'amount'])
df[['duration', 'amount','Age (years)']]= scaler.fit_transform(df[['duration', 'amount','Age (years)']])
 
#print("Scaled Dataset Using MinMaxScaler")
df.head()
# Out:
#    Creditability  Account Balance  duration  status  Purpose    amount  \
# 0              1                1  0.205882       4        2  0.043964
# 1              1                1  0.073529       4        0  0.140255
# 2              1                2  0.117647       2        9  0.032519
# 3              1                1  0.117647       4        0  0.103004
# 4              1                1  0.117647       4        0  0.105700
#
#    Value Savings/Stocks  Length of current employment  Instalment per cent  \
# 0                     1                             2                    4
# 1                     1                             3                    2
# 2                     2                             4                    2
# 3                     1                             3                    3
# 4                     1                             3                    4
#
#    Sex & Marital Status  ...  Duration in Current address  \
# ...

# %%
df_bkp = df.copy()
df2=df
enc = OneHotEncoder(sparse=False)
columns_to_one_hot = ['Type of apartment']
encoded_array = enc.fit_transform(df2.loc[:,columns_to_one_hot])
df_encoded = pd.DataFrame(encoded_array,columns=enc.get_feature_names_out() )
df_sklearn_encoded = pd.concat([df2,df_encoded],axis=1)
df_sklearn_encoded.drop(labels= columns_to_one_hot,axis=1,inplace=True)
df_sklearn_encoded
# Out:
#      Creditability  Account Balance  duration  status  Purpose  amount  \
# 0                1                1        18       4        2    1049
# 1                1                1         9       4        0    2799
# 2                1                2        12       2        9     841
# 3                1                1        12       4        0    2122
# 4                1                1        12       4        0    2171
# ..             ...              ...       ...     ...      ...     ...
# 995              0                1        24       2        3    1987
# 996              0                1        24       2        0    2303
# 997              0                4        21       4        0   12680
# 998              0                2        12       2        3    6468
# 999              0                1        30       2        2    6350
#
#      Value Savings/Stocks  Length of current employment  Instalment per cent  \
# ...

# %% [markdown]
# #**Ejercicio-4.**

# %%
None

# %% [markdown]
# #**Ejercicio-5.**

# %%
None

# %% [markdown]
# #**Ejercicio-6.**

# %%
None

# %% [markdown]
# ###**Fin de la Actividad de la semana 6.**
